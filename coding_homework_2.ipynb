# %% [markdown]
# <a href="https://colab.research.google.com/github/giseleismail/Neur265/blob/main/coding_homework_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Gisele Ismail
# *Neur 265*
#
# **02/18/2026**

# %%
import numpy as np
import matplotlib.pyplot as plt
import statistics as st

# %%
#import data as numpy arrays
v_rest1 = np.loadtxt('https://raw.githubusercontent.com/hallockh/neur_265_spring2026/refs/heads/main/data/v_rest_sst.csv')
v_rest2 =np.loadtxt('https://raw.githubusercontent.com/hallockh/neur_265_spring2026/refs/heads/main/data/v_rest_pvalb.csv')

# %%
#concatenate data into matrix
v_rest = np.vstack([v_rest1,v_rest2])

# %%
#print size of v_rest
print(v_rest.shape)
# Out:
# (2, 500)

# %%
#first row of v_rest
print(v_rest[0])
# Out:
# [-68.24292501 -69.60158234 -76.03420105 -71.16118393 -76.35402679
#  -70.89105013 -64.11880341 -72.8632112  -78.96890068 -55.4531032
#  -60.98506045 -66.61118807 -67.08294233 -73.90523593 -74.63317594
#  -49.27067811 -76.05053997 -65.45417595 -58.53314018 -66.28985665
#  -64.09106996 -71.49303228 -65.11718958 -73.74140637 -74.81462097
#  -71.32343356 -74.46990373 -65.03939126 -71.94757271 -73.42034054
#  -71.10602856 -61.28795481 -73.79654069 -64.48533249 -69.65824959
#  -73.71225967 -85.56860669 -57.49219704 -76.91730436 -62.61127641
#  -67.08071963 -78.45983535 -78.87342682 -76.14055703 -62.40101166
#  -72.41336346 -62.03701146 -63.30990855 -62.02654052 -73.0206111
#  -63.11713295 -70.05060087 -75.7537974  -57.15310111 -72.52368011
#  -70.86691952 -65.435009   -66.87690226 -70.79107895 -71.34088898
#  -65.70912288 -64.45794886 -62.82061958 -65.03326961 -61.37704976
#  -71.51313705 -71.54903143 -83.53790652 -68.49228492 -69.6041454
# ...

# %%
#sum of values in third column
print(v_rest[:,2].sum())
# Out:
# -151.75359464

# %%
#second to last value in second row
print(v_rest[1, -2])
# Out:
# -49.80412917

# %%
#histogram of values in first row
plt.hist(v_rest[0])
plt.xlabel('Resting Membrane Potential (mV)')
plt.ylabel('Counts')
# Out:
# Text(0, 0.5, 'Counts')

# %%
#mean values of first and second row
v_rest_mean_sst = st.mean(v_rest[0])
print(v_rest_mean_sst)

v_rest_mean_pvalb = st.mean(v_rest[1])
print(v_rest_mean_pvalb)
# Out:
# -67.73465864056
# -69.97869017908

# %% [markdown]
# The numbers are similar, however the mean resting membrane potential for sst (-67.7) is bigger than pvalb (-69.9). It is less negative.

# %%
import scipy.stats as stats

# %%
#t-test on the two rows of v_rest
stats.ttest_rel(v_rest[0], v_rest[1])
print("statistic", t_stat, "pvalue =", p_value)
# Out:
# statistic 5.908096579086378 pvalue = 6.412682046867052e-09

# %% [markdown]
# the p-value is 6.4x10^-9. Based on this number, the means are significantly different.
